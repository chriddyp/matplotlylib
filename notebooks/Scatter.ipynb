# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import matplotlib.cm as cm
from mplexporter.renderers import fig_to_plotly
from mplexporter.renderers import PlotlyRenderer
from mplexporter import Exporter
import plotly
username = 'IPython.Demo'
api_key = '1fw3zw2o13'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
x = np.random.rand(1000)
y = np.random.rand(1000)
ax.scatter(x,y)

# %%
fig_to_plotly(fig, username, api_key, notebook=True)
# Out:
# <iframe height="550" id="igraph" scrolling="no" seamless="seamless" src="https://plot.ly/~IPython.Demo/1583" width="100%"></iframe>
